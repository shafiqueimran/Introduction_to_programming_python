# %% [markdown]
# # Introduction to Computation Thinking

# %% [markdown]
# ## Computational Thinking
# ### Problem solving approach.
# ### Breaking down complex problems into smaller and manageable parts to derive solutions.
# ### Applied to various fields and everyday situaitons.

# %% [markdown]
# # Four Pillars of Computational Thinking

# %% [markdown]
# ## Decomposition
# ### Breaking down a problem into smaller, more understandable components or tasks.
# ## Pattern Recognition
# ### Identifying similarities or patterns within the problem, which can help in creating generalizable solutions.
# ## Abstraction
# ### Focus on the essential aspects while ignoring the unnecessary details.
# ## Algorithm Design
# ### Developing step-by-step instructions or procedures to solve a problem.

# %% [markdown]
# # Class Activity (Task)
# ## Plan a weekend getaway to Murree, applying the four pillars of computational thinking: decomposition, pattern recognition, abstraction, and algorithm design. Document your planning process in your notebook.
#
# ### Q. 1: How can you break down the trip planning process into smaller, manageable tasks?
# ### Q. 2: What patterns can you identify from your past travel experiences?
# ### Q. 3: What are the essential elements to consider when planning a trip?
# ### Q. 4: How can you create a step-by-step plan to ensure a successful trip?

# %% [markdown]
# # Algorithm
# ## An algorithm is a step-by-step procedure or formula for solving a problem or completing a task.
# ## It is a sequence of well-defined instructions that, when followed, lead to a specific outcome or solution.

# %% [markdown]
# # Programming

# %% [markdown]
# ## A process of creating a set of instructions that a computer can follow to perform specific tasks. These instructions are written in a programming language, which provides the syntax and semantics to define the operations the computer should execute.
# ## Syntax defines the structure or format of the code (i.e., how the code must be written). While semantics refers to the meaning of programming constructs and code. Semantics defines what the code actually does.

# %% [markdown]
# # Link to download Jupyter Notebook (anaconda)
# ## https://www.anaconda.com/download

# %% [markdown]
# # Computer System and its Components

# %% [markdown]
# ![image.png](attachment:f1001a6d-e3cc-4d8d-bd45-32b9dae53f87.png)

# %% [markdown]
# # Types of Languages CPU/Computer Understands
# ## Machine language
# ### CPU only understands the instructions that are written in the form of machine language.
# ### Machine language instructions always have an underlying binary structure in the form of 0’s and 1’s.
# ### Here’s an example: 01000001
# ## Assembly language
# ### Instead of using binary numbers for instructions, assembly language uses short words that are known as mnemonics. For example: add, mul.

# %% [markdown]
# # Compiler vs. Interpretor

# %% [markdown]
# ![image.png](attachment:b10ff490-dc30-4bb1-84ac-2dc628f0332e.png)

# %% [markdown]
# # Python
# ## The Python interpreter can run programs by reading Python statements from a file (script mode) or by executing them interactively as they are typed at the keyboard (interactive mode).
#
# ## Interactive mode: The interpreter waits for you to enter Python statements and executes each one immediately.
# ## Example:
# ## python
# ![image.png](attachment:b1e17c01-f181-45ca-816a-2907913d9e0c.png)
#
# ## Script mode: The interpreter reads and executes Python code from a file, running the entire program sequentially.

# %% [markdown]
# # The Program Development Cycle
# ![image.png](attachment:cf58f634-5ddd-4763-979b-f9f0b778f34c.png)

# %% [markdown]
# # Design a Program
# ## Flowchart
# ## A visual diagram illustrating the sequence of steps in a program.
# ### Ovals: Represent the start and end points.
# ### Parallelograms: Denote input and output operations.
# ### Rectangles: Indicate processing steps.
# ![flowchart-presentations-terminal-symbol.png.webp](attachment:20dc5ed7-1f56-4df2-90b8-0b92c83a73ab.webp)

# %% [markdown]
# ## Design a flowchart to visualize the steps involved in planning a weekend getaway to Murree, based on your documented planning process.

# %% [markdown]
# # Python Keywords
# ![image.png](attachment:bdbe1269-da4a-40e9-8916-e26118bbc8af.png)

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Numbers

# %%
3+4 #Numbers can be added/subdracted/divided/multiplied directly
# Out:
# 7

# %%
10-4
# Out:
# 6

# %%
11/3
# Out:
# 3.6666666666666665

# %%
5*2
# Out:
# 10

# %% [markdown]
# # Comments in Python

# %%
#Comments can be used while writing python codes with # and no space between # and comment as I did in line 18

# %% [markdown]
# # Variable
# ## A variable is a named container that stores a value.
# ### For example:
# ### Name = "Imran"
# ### Age = 35
# ### Name stores the value "Imran" which is a string.
# ### Age stores the value "35" which is an integer.
# ### You can then use these variables in your code, like printing them:
# ### print(Name)
# ### print(Age)

# %%
Name = "Imran"
Age = 35

# %%
print (Name)
print (Age)
# Out:
# Imran
# 35

# %%
#In programming, it's common practice to write names in lowercase. This is because using all lowercase letters 
#avoids the need to press the Shift key, making typing more efficient and reducing errors. 
#Adopting this convention helps maintain consistency and readability in your code.

# %%
x = 11

# %%
y = 67

# %%
print (x+y)
# Out:
# 78

# %% [markdown]
# # Python is case-sensitive.
# ## This means that variables with different capitalization are considered distinct.
# ## For example, 'x' variable and 'X' variable would be treated as two separate variables.
# ## This is true for all identifiers in Python, including variable names, function names, and class names.
# ## Make sure to be consistent with your capitalization to avoid errors.

# %%
X = 3

# %%
print (x)
print (X)
# Out:
# 11
# 3
